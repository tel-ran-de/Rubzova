# %% [markdown]
# 1. Создайте список студентов, который сдали физику на 5

# %% [markdown]
# 2. Список студентов, упорядоченный по номеру зачетки

# %% [markdown]
# 3. Список пар, который лексикографически упорядочен по возрастанию имен первого студента и убыванию второго

# %% [markdown]
# 4. Список пар, в которых встречаются студенты с одинаковым номером зачетки

# %% [markdown]
# 5. Список пар, в которых не встречаются студенты с одинаковым номером зачетки

# %% [markdown]
# 6. Список студентов, которые учатся на 4 и выше.

# %% [markdown]
# ## Задание по БД  Sakila

# %% [markdown]
# ! https://dev.mysql.com/doc/sakila/en/sakila-structure.html

# %% [markdown]
# ## Дополнительные материалы

# %% [markdown]
#  - https://www.programiz.com/sql/join
#  - https://function-x.ru/sql_join.html

# %% [markdown]
# Эти вопросы уже были

# %% [markdown]
# - У каких актеров имя Скарлетт?
# - У каких актеров фамилия Йоханссон?
# - Сколько существует различных фамилий актеров?
# - Какие фамилии не повторяются?
# - Какие фамилии встречаются более одного раза?
# - Какой актер снялся в большинстве фильмов?
# - Можно ли арендовать «Академию динозавров» в магазине 1?
# - Вставьте запись, изображающую, что Мэри Смит арендует «Академию динозавров» у Майка Хиллиера сегодня в магазине 1.(Mike Hillyer  и‘Academy Dinosaur’)
# - Когда выйдет «Академия динозавров»?(‘Academy Dinosaur’)
# - Какова средняя продолжительность всех фильмов в базе данных сакила?
# - Какова средняя продолжительность фильмов по категориям?
# - Почему этот запрос возвращает пустой набор?

# %% [markdown]
# 1. Вывести имена и фамилии всех актеров из таблицы actor.
# 2. Отображать имя и фамилию каждого актера в одном столбце заглавными буквами. Назовите столбец Actor Name.

# %% [markdown]
# 3.  Вам нужно найти идентификационный номер, имя и фамилию актера, о котором вы знаете только имя «Джо». Какой запрос вы бы использовали для получения этой информации? ('Joe')
# 4. Найдите всех актеров, чьи фамилии содержат буквы GEN
# 5. Найдите всех актеров, чьи фамилии содержат буквы LI. На этот раз расположите строки по фамилии и имени в таком порядке
# 6. Используя IN, отобразите столбцы country_idи countryдля следующих стран: Афганистан, Бангладеш и Китай

# %% [markdown]
# 7.  Добавьте middle_nameстолбец в таблицу actor. Расположите его между first_nameи last_name.
# 8. Вы понимаете, что у некоторых из этих актеров невероятно длинные фамилии. Измените тип данных middle_nameстолбца на blobs.
# 9. Теперь удалите middle_name столбец.

# %% [markdown]
# 10. Перечислите фамилии актеров, а также сколько актеров носят эту фамилию. ВЫБРАТЬ last_name, COUNT(last_name) FROM группы актеров по last_name
# 11. Укажите фамилии актеров и количество актеров с этой фамилией, но только для имен, которые являются общими как минимум для двух актеров.

# %% [markdown]
# 12. Используется JOIN для отображения имени и фамилии, а также адреса каждого сотрудника. Используйте таблицы staffи addres
# 13.  Используйте JOINдля отображения общей суммы, набранной каждым сотрудником в августе 2005 года. Используйте таблицы staffи payment
# 14. Перечислите каждый фильм и количество актеров, которые указаны для этого фильма. Используйте таблицы film_actorи film. Используйте внутреннее соединение.
# 15. Сколько копий фильма Hunchback Impossible существует в системе инвентаризации?
# 16. Используя таблицы paymentи customerкоманду JOIN, перечислите общую сумму, уплаченную каждым покупателем. Список клиентов в алфавитном порядке по фамилии

# %% [markdown]
# 17. Музыка Queen и Криса Кристофферсона пережила маловероятное возрождение. Как непреднамеренное следствие, популярность фильмов, начинающихся с букв K, Qтакже резко возросла. Используйте подзапросы для отображения названий фильмов, начинающихся с букв Kи Qнаписанных на английском языке.
# 18. Используйте подзапросы для отображения всех актеров, которые появляются в фильме Alone Trip.
# 19. Вы хотите запустить маркетинговую кампанию по электронной почте в Канаде, для которой вам понадобятся имена и адреса электронной почты всех канадских клиентов. Используйте объединения для получения этой информации.
# 20. Продажи среди молодых семей отстают, и вы хотите рекламировать все семейные фильмы. Определите все фильмы, отнесенные к категории семейных фильмов.
# 21. Отображение наиболее часто снимаемых фильмов в порядке убывания.
# 22. Напишите запрос, чтобы показать, сколько бизнеса в долларах принес каждый магазин.
# 23. Напишите запрос для отображения для каждого магазина его идентификатора магазина, города и страны.
# 24. Перечислите пять жанров с наибольшим валовым доходом в порядке убывания.

# %% [markdown]
# Вопросы на англ (эти же) https://github.com/coreyclip/Sakila-practice/blob/master/solution.md
